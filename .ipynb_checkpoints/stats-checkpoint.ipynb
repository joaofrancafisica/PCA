# %%
import glob #to read the files
import json #to work if .json

# %%
#sn_names=glob.glob("*.dat")
#print(len(sn_names))

# %%
#sn_names[0][:-4]

# %%
'''
f = open("names_training.txt", 'w')
for i in range(0,len(sn_names)):
    
    f.write(sn_names[i][:-4]+"\n")

f.close()
'''
# Out:
# '\nf = open("names_training.txt", \'w\')\nfor i in range(0,len(sn_names)):\n    \n    f.write(sn_names[i][:-4]+"\n")\n\nf.close()\n'

# %%
#sn_names[0]

# %%
'''
for i in range(0,len(sn_names)):
    
    sn_names[i] = sn_names[i][:-4]
'''
# Out:
# '\nfor i in range(0,len(sn_names)):\n    \n    sn_names[i] = sn_names[i][:-4]\n'

# %%
file = open("./factors.txt")
lines = file.readlines()
file.close()

# %%
f_names = []
f_values = []

# %%
for line in lines:
    if line.startswith('#'): continue
    co=line.rstrip().replace('INDEF','Nan').split()

    f_names.append(co[0])
    f_values.append(co[1])

# %%
# %run /home/joao/Documentos/templates/functions.ipynb

# %%
redshifts = []

# %%
for i in range(0,len(f_names)):
    print(f_names[i])
    name = f_names[i]
    
    with open("/home/joao/Documentos/templates/"+f_names[i]+".json", "r") as read_file:
        data = json.load(read_file)
    
    redshifts.append(redshift_value(data[name]))
# Out:
# SN2000cx
# 0.007929
# SN1997bq
# 0.0109
# SN2003fa
# 0.006004
# SN2005eu
# 0.034901
# SN2009D
# 0.025007
# SN2007ax
# 0.006861
# SN2008s1
# 0.0221
# SN2006D
# 0.008529
# SN1998bp
# 0.01043
# iPTF14bdn
# 0.01558
# SN2005bl
# 0.02406
# SN2002fk
# 0.007132
# SN1999gp
# 0.02675
# SN2009ad
# 0.02834
# SN2007F
# 0.023591
# SN1999ac
# 0.0115
# SN2008ar
# 0.026147
# SN2002cs
# 0.01577
# SN2002cr
# 0.00948
# SN2007bc
# 0.02077
# SN2006ac
# 0.023106
# SN1995al
# 0.00514
# SN1996X
# 0.00749
# SN2006sr
# 0.02414
# SN2005cf
# 0.006461
# SN2006bt
# 0.032156
# SN1998dh
# 0.00897
# SN2004at
# 0.023131
# SN2000cn
# 0.02349
# SN2001en
# 0.015871
# SN1994ae
# 0.004266
# SN2003it
# 0.025121
# SN2001da
# 0.017195
# SN2005am
# 0.007899
# SN2002bo
# 0.00424
# SN2007on
# 0.006494
# SN2002hw
# 0.017535
# SN2002de
# 0.028116
# SN2001bf
# 0.015501
# SN2001bg
# 0.007122
# SN2015bp
# 0.004069
# SN1994D
# 0.00149
# SN2007qe
# 0.0239
# SN2002ha
# 0.014046
# iPTF13dge
# 0.015854
# SN2006gt
# 0.044771
# SN1999by
# ...

# %%
len(redshifts)
# Out:
# 77

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

plt.hist(redshifts, bins= 30, histtype = 'bar', color = 'goldenrod')
plt.xlabel('redshift')
plt.ylabel('N')
plt.savefig('redshifthistplot', format='png')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
max(redshifts)
# Out:
# 0.068

# %%
file = open("/home/joao/Documentos/templates/t0_values.txt")
lines = file.readlines()
file.close()

# %%
t0_names = []
t0_values = []

# %%
for line in lines:
    if line.startswith('#'): continue
    co=line.rstrip().replace('INDEF','Nan').split()

    t0_names.append(co[0])
    t0_values.append(co[1])

# %%
from astropy.time import Time #to time converting
from astropy import units #time correction
from astropy.coordinates import SkyCoord #time correction

# %%
histt0 = []

# %%
for i in range(0, len(f_names)):
    
    print(f_names[i])
    
    with open("/home/joao/Documentos/templates/"+f_names[i]+".json", "r") as read_file:
        data = json.load(read_file)
    
    idxname = [j for j, e in enumerate(t0_names) if e == f_names[i]]
    
    #idxname = t0_names.index(f_names[i])
    if len(idxname) > 0:
        
        print(float(t0_values[idxname[0]]))
        
        histt0.append(float(t0_values[idxname[0]]) - float(max_time(data[f_names[i]])))
# Out:
# SN2000cx
# 51752.0
# SN1997bq
# 50557.2
# SN2003fa
# 52806.9
# SN2005eu
# 53660.6
# SN2009D
# SN2007ax
# 54187.2
# SN2008s1
# 54612.1
# SN2006D
# 53756.8
# SN1998bp
# 50935.6
# iPTF14bdn
# 56821.4
# SN2005bl
# 53481.9
# SN2002fk
# 52547.7
# SN1999gp
# 51549.6
# SN2009ad
# 54885.7
# SN2007F
# 54123.5
# SN1999ac
# 51250.2
# SN2008ar
# 54534.4
# SN2002cs
# 52409.4
# SN2002cr
# 52408.5
# SN2007bc
# 54198.9
# SN2006ac
# 53781.2
# SN1995al
# 50028.0
# SN1996X
# 50190.3
# SN2006sr
# 54090.9
# SN2005cf
# 53533.4
# SN2006bt
# 53856.6
# SN1998dh
# 51029.2
# SN2004at
# 53091.7
# SN2000cn
# 51706.6
# SN2001en
# 52192.4
# SN1994ae
# 49685.5
# SN2003it
# 52937.4
# SN2001da
# 52107.3
# SN2005am
# 53436.2
# SN2002bo
# 52355.9
# SN2007on
# 54419.5
# SN2002hw
# 52595.2
# SN2002de
# 52433.2
# SN2001bf
# 52044.2
# SN2001bg
# SN2015bp
# 57112.6
# SN1994D
# 49432.4
# SN2007qe
# 54428.2
# SN2002ha
# 52581.4
# iPTF13dge
# 56555.6
# SN2006gt
# SN1999by
# 51308.2
# SN1999aa
# 51232.1
# SN1998aq
# 50930.7
# ...

# %%
histt0mod = []
for i in range(0,len(histt0)):
    
    if abs(histt0[i]) < 50:
        
        histt0mod.append(histt0[i])

# %%
# %matplotlib notebook

plt.hist(histt0mod, bins= 30, histtype = 'bar', color = 'goldenrod')
plt.xlabel('$t_0$ calculado - $t_0$ fornecido')
plt.ylabel('N')
plt.xlim(-22, 22)
plt.savefig('compvalorest0.png', format='png', dpi=600)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
histt0
# Out:
# [0.0,
#  -0.8000000000029104,
#  6.900000000001455,
#  -3.400000000001455,
#  1.1999999999970896,
#  3.099999999998545,
#  -1.1999999999970896,
#  0.5999999999985448,
#  1.4000000000014552,
#  -0.09999999999854481,
#  1.6999999999970896,
#  363.59999999999854,
#  11.69999999999709,
#  1.5,
#  0.19999999999708962,
#  0.4000000000014552,
#  2.400000000001455,
#  1.5,
#  -4.099999999998545,
#  3.1999999999970896,
#  0.0,
#  -0.6999999999970896,
#  -2.099999999998545,
#  0.4000000000014552,
#  1.5999999999985448,
#  0.19999999999708962,
#  -0.3000000000029104,
#  -0.4000000000014552,
#  -0.5999999999985448,
#  1.5,
#  2.400000000001455,
#  1.3000000000029104,
#  0.19999999999708962,
#  -1.0999999999985448,
#  3.5,
#  2.1999999999970896,
#  2.1999999999970896,
#  -7.80000000000291,
#  4.599999999998545,
#  0.4000000000014552,
#  -2.8000000000029104,
#  6.400000000001455,
#  2.599999999998545,
#  0.19999999999708962,
#  1.0999999999985448,
#  0.6999999999970896,
#  2.900000000001455,
# ...
