# %%
# %matplotlib inline

# %%
import scipy as sp
import scipy.interpolate
import numpy as np
import glob #to read the files
from sklearn.decomposition import PCA
from ipywidgets import *
from tabulate import tabulate #to export in table format
from scipy import interpolate
import scipy.interpolate as interp
from scipy.integrate import quad
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
import scipy.integrate as integrate
from astropy import constants as const
import sncosmo

# %%
csp = sncosmo.get_magsystem('csp')
N = (1/(csp.zpbandflux("cspv9844")))

# %%
N
# Out:
# 1.6839572518342795e-06

# %%
filter_y = []
filter_z = []

# %%
file = open("V_tel_ccd_atm_ext_1.2.txt")
lines = file.readlines()
file.close()

# %%
for line in lines:

    if line.startswith('#'): continue
    co=line.rstrip().replace('INDEF','Nan').split()

    filter_y.append(co[0])
    filter_z.append(co[1])

filter_y = np.array(filter_y, dtype=float)
filter_z = np.array(filter_z, dtype=float)

# %%
f_filter = interp1d(filter_y, filter_z)

# %%
# %matplotlib notebook
plt.plot(filter_y, filter_z, 'k')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
x = np.linspace(-10,50,61)
y = np.linspace(3000,9000,601)

# %%
file = open("max_valuesV.txt")
lines = file.readlines()
file.close()

snname = []
maxvalue = []

for line in lines:

    if line.startswith('#'): continue
    co=line.rstrip().replace('INDEF','Nan').split()

    maxvalue.append(co[1])
    snname.append(co[0])

maxvalue = np.array(maxvalue, dtype=float)

# %%
#for i in range(0,len(snname)):
    
#    snname[i] = snname[i][:-5]

# %%
sn_names=glob.glob("*.dat")
print(len(sn_names))
# Out:
# 112

# %%
for i in range(0,len(sn_names)):

    sn_names[i] = sn_names[i][:-4]

# %%
factors = []
names = []

# %%
#hist = []

# %%
max_list = []

# %%
#sn_names = ["SN2012fr"]

# %%
list_data = []
for k in range(0,len(sn_names)):
    
    x_lc = []
    z_lc = []

    print(sn_names[k])

    N = sn_names[k]+".dat"


    file = open(N)
    lines = file.readlines()
    file.close()

    xtemp = []

    for line in lines:

        if line.startswith('#'): continue
        co=line.rstrip().replace('INDEF','Nan').split()

        xtemp.append(co[0])

    xtemp = np.array(xtemp, dtype=float)


    z = np.reshape(xtemp, (601, 61))

    zz = []
    xx = []
    yy = []

    for i in range(0,len(y)):

        for j in range(0,len(x)):

            zz.append(z[i][j])
            xx.append(x[j])
            yy.append(y[i])
            
            
            

    wavetest = []
    
    for i in range(0,len(zz)):
    
        if zz[i] != 0:

            wavetest.append(yy[i])
    
    minvar = False
    maxvar = False
    
    for i in range(0,len(wavetest)):

        if 4600 -50 < wavetest[i] < 4600 + 50:
            minvar = True
            #print("possui minimo")

        if 6580 - 50 < wavetest[i] < 6580 + 50:
            maxvar = True
            #print("possui maximo")
    print(minvar, maxvar)
    
    
    if maxvar == True and minvar == True:
        
        print("passou")

        for j in range(0,len(x)):

            y_temp = []
            z_temp = []

            for i in range(0,len(xx)):

                if xx[i] == x[j]:

                    y_temp.append(yy[i])
                    z_temp.append(zz[i])

            f = interp1d(y_temp, z_temp)

            def S(x): return f(x)*f_filter(x)

            z_lc.append(integrate.quad(S, min(filter_y), max(filter_y))[0]*N)
            x_lc.append(x[j])        

        list_data.append([x_lc, z_lc]) 


        #print(z_lc)

        #print(j)

        maxvaluecalc = max(z_lc)

        #print(maxvaluecalc)
        if sn_names[k] in snname:
            print("ok")
            idx = snname.index(sn_names[k])
            max_list.append([maxvaluecalc, maxvalue[idx], sn_names[k]])  

            factors.append(maxvalue[idx]/maxvaluecalc)
            names.append(sn_names[k])
# Out:
# SN2000cx
# True True
# passou
# ok
# SN2001ay
# True True
# passou
# SN2001eh
# True True
# passou
# ok
# SN1997bq
# True True
# passou
# ok
# SN2003fa
# True True
# passou
# ok
# SN2009ig
# True False
# SN2008bc
# True True
# passou
# ok
# SN2005eu
# True True
# passou
# ok
# SN2009D
# True True
# passou
# ok
# SN2007ax
# True True
# passou
# ok
# SN2006D
# True True
# passou
# ok
# SN1999dq
# True True
# passou
# ok
# SN1998bp
# True True
# passou
# ok
# iPTF14bdn
# True True
# passou
# ok
# ASASSN-14lp
# True True
# passou
# ok
# SN2002fk
# True True
# passou
# ok
# SN2003W
# True True
# passou
# ok
# SN2008ia
# True True
# passou
# ok
# SN1997br
# True True
# passou
# ok
# SN2004gs
# True True
# passou
# ok
# SN2009ad
# True True
# passou
# ok
# SN2007F
# True True
# passou
# ok
# SN2013dy
# True True
# passou
# ok
# SN1999ac
# True True
# passou
# ok
# SN2008ar
# True True
# passou
# ok
# 2015bp
# True True
# passou
# SN2002cs
# True True
# passou
# ok
# SN2002cr
# True True
# passou
# ok
# SN1997bp
# True True
# passou
# ok
# SN2007bc
# True True
# passou
# ok
# SN2005ke
# True True
# passou
# ok
# 2006S
# True True
# passou
# SN2005hk
# True True
# passou
# ok
# SN1996X
# True True
# passou
# ok
# SN2005ki
# True True
# passou
# ok
# SN2005cf
# True True
# passou
# ok
# SN2006bt
# True True
# passou
# ok
# SN2005el
# True True
# passou
# ok
# SN1998dh
# True True
# passou
# ok
# SN2007S
# True True
# passou
# ok
# SN2004at
# True True
# passou
# ok
# SN2000cn
# True True
# passou
# ok
# SN2006S
# True True
# passou
# ok
# SN1997E
# True True
# passou
# ok
# SN2007bd
# True True
# passou
# ok
# SN1972E
# True True
# passou
# SN2002er
# True True
# passou
# ok
# SN2002bz
# True True
# passou
# SN2001en
# True True
# passou
# ok
# SN2000dk
# True True
# passou
# ok
# SN1994ae
# True True
# passou
# ok
# SN2008C
# True True
# passou
# SN2005am
# True True
# passou
# ok
# SN2002bo
# True True
# passou
# ok
# SN2007on
# True True
# passou
# ok
# SN2007cq
# True True
# passou
# <ipython-input-17-a7c82ab64416>:88: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   z_lc.append(integrate.quad(S, min(filter_y), max(filter_y))[0])
# ok
# SN2005hc
# True True
# passou
# ok
# SN1992A
# True True
# passou
# ok
# LSQ12fxd
# True True
# passou
# LSQ12gdj
# True True
# passou
# ok
# SN2002de
# True True
# passou
# ok
# SN2016coj
# True True
# passou
# ok
# SN2001bf
# True True
# passou
# ok
# SN2001bg
# True True
# passou
# SN2015bp
# True True
# passou
# ok
# SN1994D
# True True
# passou
# ok
# SN2007qe
# True True
# passou
# ok
# SN2002ha
# True True
# passou
# ok
# iPTF13dge
# True True
# passou
# ok
# SN2005na
# True True
# passou
# ok
# SN2002dj
# True True
# passou
# ok
# SN1999by
# True True
# passou
# ok
# SN1999aa
# True True
# passou
# ok
# SN1998aq
# True True
# passou
# ok
# SN2006ax
# True True
# passou
# ok
# SN2001gc
# True True
# passou
# SN2002dp
# True True
# passou
# ok
# SN2004ef
# True True
# passou
# ok
# SN2017fgc
# True True
# passou
# ok
# SN2012hr
# True True
# passou
# ok
# SN2009Y
# True True
# passou
# ok
# SN1995D
# True True
# passou
# ok
# SN2004as
# True True
# passou
# ok
# SN2002fb
# True True
# passou
# ok
# SN2008ec
# True True
# passou
# ok
# SN2010ae
# True True
# passou
# SN2008Z
# True True
# passou
# ok
# SN2012fr
# True True
# passou
# ok
# SN2007af
# True True
# passou
# ok
# SN2006cp
# True True
# passou
# ok
# SN2007kk
# True True
# passou
# ok
# SN2005M
# True True
# passou
# ok
# SN2007hj
# True True
# passou
# ok
# SN2003cq
# True True
# passou
# ok
# LSQ12gpw
# True True
# passou
# SN2005kc
# True True
# passou
# ok
# SN2001V
# True True
# passou
# ok
# SN2006gr
# True True
# passou
# ok
# SN2001cp
# True True
# passou
# ok
# SN2007if
# True True
# passou
# SN2003kf
# True True
# passou
# ok
# 1972E
# True True
# passou
# SN1999ee
# True True
# passou
# ok
# SN2013bh
# True True
# passou
# SN2003du
# True True
# passou
# ok
# SN2012ht
# False True
# SN2017erp
# True True
# passou
# ok
# SN2001ep
# True True
# passou
# ok
# SN2001fe
# True True
# passou
# ok
# SN2008ha
# False True
# SN2006kf
# True True
# passou
# ok
# SN2008bf
# True True
# passou
# ok

# %%
#sn_names

# %%
# %matplotlib notebook

for i in range(0,len(list_data)):
    
    plt.plot(list_data[i][0],list_data[i][1])
    
    
#plt.ylim(0,7*10**(-11))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# %matplotlib inline
plt.plot(x_lc,z_lc,'ko')
plt.show()

# %%
max(z_lc)
# Out:
# 9.948727831698165e-13

# %%
z_lc
# Out:
# [2.790037883107631e-13,
#  3.432025538192778e-13,
#  4.093269909814288e-13,
#  4.832414703484988e-13,
#  5.589132484842539e-13,
#  6.343894005816089e-13,
#  7.075648371253884e-13,
#  7.762786667815903e-13,
#  8.38430412740774e-13,
#  8.920903521356952e-13,
#  9.356105864394563e-13,
#  9.67715767575046e-13,
#  9.875817372996281e-13,
#  9.948727831698165e-13,
#  9.897600073533582e-13,
#  9.72897840995064e-13,
#  9.453740802320627e-13,
#  9.086361418745934e-13,
#  8.643867391292289e-13,
#  8.144833529575469e-13,
#  7.608259540725926e-13,
#  7.052517475453404e-13,
#  6.494450157977318e-13,
#  5.948677145021171e-13,
#  5.427146347656235e-13,
#  4.93887290794826e-13,
#  4.4899574982916335e-13,
#  4.083820422962024e-13,
#  3.7215528380782906e-13,
#  3.4023792374893207e-13,
#  3.124166204080254e-13,
#  2.8839240941280845e-13,
#  2.678230474807099e-13,
#  2.503587765354111e-13,
#  2.356659045027838e-13,
#  2.2344084514621366e-13,
#  2.1341318096199036e-13,
#  2.0534214556256415e-13,
#  1.990076845822358e-13,
#  1.9419883474248062e-13,
#  1.9070314958129168e-13,
#  1.8829859603509138e-13,
#  1.8674932085501762e-13,
#  1.8580597302581247e-13,
#  1.8521208377313832e-13,
#  1.8471200455555825e-13,
#  1.8406381514474886e-13,
#  1.8305253551320755e-13,
#  1.8150160535328894e-13,
#  1.792843584123272e-13,
#  1.7633061559779929e-13,
#  1.7262937421297429e-13,
#  1.6822783326070387e-13,
#  1.6322493451928855e-13,
#  1.5776202905197155e-13,
#  1.5201033159845156e-13,
#  1.4615690735293297e-13,
#  1.4038935637435657e-13,
#  1.3488255427212383e-13,
#  1.29785551499943e-13,
#  1.252128904335505e-13]

# %%
save_path = '/home/joao/Documentos/PCA'

# %%
table = []
for l in range(0,len(names)):
    table.append((names[l],factors[l]))

name_of_file = "factors"

completeName = os.path.join(save_path, name_of_file+".txt")

f = open(completeName, 'w')
f.write(tabulate(table, tablefmt="plain"))
f.close()

# %%
factors
# Out:
# [168054646239.96884,
#  324565611357.07837,
#  339309460989.2345,
#  336293077072.02203,
#  365236690900.5184,
#  262119581207.0954,
#  285232988979.46497,
#  324117793621.15784,
#  319382873391.0974,
#  252649462290.97394,
#  261035282571.70065,
#  245862687836.71033,
#  3442926208.042351,
#  395880768034.18475,
#  210902484847.46014,
#  346708478350.6117,
#  266777926928.9697,
#  281803667128.7048,
#  430414080813.66016,
#  222169432870.11713,
#  276613828296.3359,
#  227523712955.5,
#  192529407204.32013,
#  333064153691.58844,
#  289869779356.7583,
#  257053561659.39938,
#  333227660275.62714,
#  395832948871.5415,
#  288361740013.35474,
#  317600182926.85974,
#  773375802951.7672,
#  271289225607.4553,
#  307078338745.8782,
#  377816805332.5326,
#  188358307333.3991,
#  310937274383.25476,
#  285217966255.9951,
#  402673386054.06104,
#  272282756584.43912,
#  376822042890.10706,
#  333376684682.79047,
#  287409520257.9377,
#  289997850248.2617,
#  331631501150.64343,
#  422307917445.737,
#  280381136201.9637,
#  382083015214.1456,
#  408843349772.7135,
#  0.00036459739403073066,
#  374769273225.7692,
#  274334392565.28262,
#  228691003971.10406,
#  233390447779.35785,
#  0.00027615056251225766,
#  288422586398.9362,
#  326468074368.13245,
#  400683511949.7884,
#  446904806248.06433,
#  218257733053.90878,
#  253177996154.89243,
#  295525316569.1267,
#  270782120779.30844,
#  329607033940.7844,
#  342488579803.7557,
#  264801270717.75992,
#  273381833073.59528,
#  346793815800.7567,
#  328105478842.63776,
#  0.00020632561881943874,
#  146538944089.67963,
#  336454515683.51556,
#  369205184182.2029,
#  173667887901.75867,
#  323813247738.51746,
#  0.00023823284552447382,
#  137480140975.83685,
#  289074663880.3744,
#  250784286176.93973,
#  257548617811.897,
#  349252558434.59875,
#  289132181894.41113,
#  223260156328.05792,
#  365129910295.5738,
#  289036956473.4604,
#  204364024327.0148,
#  305305681248.6915,
#  291106883387.1042,
#  249885790987.86456,
#  110707515910.23924,
#  293795793937.6614,
#  0.00042116908906352803,
#  272223358809.47183,
#  387465311288.3244,
#  428550346286.81854,
#  329497404638.56464]
