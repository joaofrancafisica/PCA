# %%
# %matplotlib inline

# %%
import scipy as sp
import scipy.interpolate
import numpy as np
import glob #to read the files
from sklearn.decomposition import PCA
from ipywidgets import *
from tabulate import tabulate #to export in table format
from scipy import interpolate
import scipy.interpolate as interp
from scipy.integrate import quad
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d
import scipy.integrate as integrate
from astropy import constants as const

# %%
filter_y = []
filter_z = []

# %%
file = open("V_tel_ccd_atm_ext_1.2.txt")
lines = file.readlines()
file.close()

# %%
for line in lines:

    if line.startswith('#'): continue
    co=line.rstrip().replace('INDEF','Nan').split()

    filter_y.append(co[0])
    filter_z.append(co[1])

filter_y = np.array(filter_y, dtype=float)
filter_z = np.array(filter_z, dtype=float)

# %%
f_filter = interp1d(filter_y, filter_z)

# %%
# %matplotlib notebook
plt.plot(filter_y, filter_z, 'k')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
x = np.linspace(-10,50,61)
y = np.linspace(3000,9000,601)

# %%
file = open("max_valuesV.txt")
lines = file.readlines()
file.close()

snname = []
maxvalue = []

for line in lines:

    if line.startswith('#'): continue
    co=line.rstrip().replace('INDEF','Nan').split()

    maxvalue.append(co[1])
    snname.append(co[0])

maxvalue = np.array(maxvalue, dtype=float)

# %%
sn_names=glob.glob("*.dat")
print(len(sn_names))
# Out:
# 85

# %%
for i in range(0,len(sn_names)):

    sn_names[i] = sn_names[i][:-4]

# %%
factors = []
names = []

# %%
#hist = []

# %%
max_list = []

# %%
#sn_names = ["SN2012fr"]

# %%
list_data = []
for k in range(0,len(sn_names)):
    
    x_lc = []
    z_lc = []

    print(sn_names[k])

    N = sn_names[k]+".dat"


    file = open(N)
    lines = file.readlines()
    file.close()

    xtemp = []

    for line in lines:

        if line.startswith('#'): continue
        co=line.rstrip().replace('INDEF','Nan').split()

        xtemp.append(co[0])

    xtemp = np.array(xtemp, dtype=float)


    z = np.reshape(xtemp, (601, 61))

    zz = []
    xx = []
    yy = []

    for i in range(0,len(y)):

        for j in range(0,len(x)):

            zz.append(z[i][j])
            xx.append(x[j])
            yy.append(y[i])
            
            
            

    wavetest = []
    
    for i in range(0,len(zz)):
    
        if zz[i] != 0:

            wavetest.append(yy[i])
    
    minvar = False
    maxvar = False
    
    for i in range(0,len(wavetest)):

        if 4760 -50 < wavetest[i] < 4760 + 50:
            minvar = True
            #print("possui minimo")

        if 6560 - 50 < wavetest[i] < 6560 + 50:
            maxvar = True
            #print("possui maximo")
    print(minvar, maxvar)
    
    
    if maxvar == True and minvar == True:
        
        #print("passou")

        for j in range(0,len(x)):

            y_temp = []
            z_temp = []

            for i in range(0,len(xx)):

                if xx[i] == x[j]:

                    y_temp.append(yy[i])
                    z_temp.append(zz[i])

            f = interp1d(y_temp, z_temp)

            def S(x): return f(x)*f_filter(x)

            z_lc.append(integrate.quad(S, min(filter_y), max(filter_y))[0])
            x_lc.append(x[j])        

        list_data.append([x_lc, z_lc]) 


        #print(z_lc)

        #print(j)

        maxvaluecalc = max(z_lc)

        #print(maxvaluecalc)
        if sn_names[k] in snname:
            idx = snname.index(sn_names[k])
            max_list.append([maxvaluecalc, maxvalue[idx], sn_names[k]])  

            factors.append(maxvalue[idx]/maxvaluecalc)
            names.append(sn_names[k])
# Out:
# SN2009aa
# True True
# SN2000cx
# True True
# SN1997bq
# True True
# SN2003fa
# True True
# SN2005eu
# True True
# SN2009D
# True True
# SN2007ax
# True True
# SN2008s1
# True True
# SN2006D
# True True
# SN1998bp
# True True
# SN2013ew
# True True
# iPTF14bdn
# True True
# SN2005bl
# True True
# SN2002fk
# True True
# SN1999gp
# True True
# SN2002jy
# True True
# SN1997dt
# True True
# SN2009ad
# True True
# SN2007F
# True True
# SN1999ac
# True True
# SN2008ar
# True True
# SN2002cs
# True True
# SN2002cr
# True True
# SN2007bc
# True True
# SN2006ac
# True True
# SN1995al
# True True
# SN1996X
# True True
# SN2006sr
# True True
# SN2005cf
# True True
# SN2006bt
# True True
# SN2003kc
# True True
# SN1998dh
# True True
# SN2004at
# True True
# SN2000cn
# True True
# SN1972E
# True True
# SN2001en
# True True
# SN1994ae
# True True
# SN2003it
# True True
# SN2001da
# True True
# SN2005am
# True True
# SN2002bo
# True True
# SN2007on
# True True
# SN2002hw
# True True
# SN2002de
# True True
# SN2001bf
# True True
# SN2001bg
# True True
# SN2015bp
# True True
# SN1994D
# True True
# SN2007qe
# True True
# SN2002ha
# True True
# iPTF13dge
# True True
# SN2006gt
# True True
# SN1999by
# True True
# SN1999aa
# True True
# SN1998aq
# True True
# SN2006ax
# True True
# SN2006gj
# True True
# SN2002dp
# True True
# SN2012hr
# True True
# SN2009Y
# True True
# SN1995D
# True True
# SN2007le
# True True
# SN2004fu
# True True
# SN2002fb
# True True
# SN2010ae
# True True
# SN2002eu
# True True
# SN2008Z
# True True
# SN2012fr
# True True
# SN2007af
# True True
# SN2006cp
# True True
# SN2007ux
# True True
# SN2007kk
# True True
# SN2007hj
# True True
# SN2005kc
# True True
# SN2001V
# True True
# SN2007ci
# True True
# SN2006gr
# True True
# SN2001cp
# True True
# SN2003kf
# True True
# SN2013bh
# True True
# SN2003du
# True True
# SN2002ck
# True True
# SN2001N
# True True
# SN2001ep
# True True
# SN2008bf
# True True

# %%
max_list
# Out:
# [[1.7621775211319695e-11, 2.28965, 'SN2000cx'],
#  [2.3327284086722013e-12, 0.854569, 'SN1997bq'],
#  [4.603796706824166e-13, 0.104722, 'SN2003fa'],
#  [5.243088047675419e-13, 0.0955003, 'SN2005eu'],
#  [7.090041496238501e-13, 0.129673, 'SN2007ax'],
#  [9.565900397310389e-13, 0.208848, 'SN2008s1'],
#  [4.597637697256766e-12, 1.0081, 'SN2006D'],
#  [2.110646392770259e-12, 0.304505, 'SN1998bp'],
#  [3.622948313277494e-12, 0.64758, 'iPTF14bdn'],
#  [7.551320881684737e-14, 0.0191401, 'SN2005bl'],
#  [8.745147894337381e-12, 2.51763, 'SN2002fk'],
#  [1.5256030786717e-12, 0.187505, 'SN1999gp'],
#  [3.9426162114917083e-13, 0.135283, 'SN2009ad'],
#  [1.5975983659419618e-12, 0.224065, 'SN2007F'],
#  [7.828639306596954e-12, 1.04966, 'SN1999ac'],
#  [9.103280980481225e-13, 0.161084, 'SN2008ar'],
#  [1.4433910402026274e-12, 0.341175, 'SN2002cs'],
#  [5.14160216753563e-12, 1.04919, 'SN2002cr'],
#  [9.924460184069117e-13, 0.227122, 'SN2007bc'],
#  [7.459802705229511e-13, 0.175172, 'SN2006ac'],
#  [8.680029079562209e-12, 2.33701, 'SN1995al'],
#  [1.0941272306035188e-11, 2.64191, 'SN1996X'],
#  [8.617536822029121e-13, 0.13654, 'SN2006sr'],
#  [1.0656868116587713e-11, 1.94938, 'SN2005cf'],
#  [4.1147732630553264e-13, 0.0791569, 'SN2006bt'],
#  [9.830418786438868e-12, 1.19369, 'SN1998dh'],
#  [1.5084523234491812e-12, 0.289099, 'SN2004at'],
#  [2.910880334130441e-13, 0.106885, 'SN2000cn'],
#  [1.8286468474212157e-12, 0.429119, 'SN2001en'],
#  [1.1549005491638001e-11, 2.86681, 'SN1994ae'],
#  [8.207788847905335e-13, 0.123653, 'SN2003it'],
#  [2.95514765459997e-12, 0.287053, 'SN2001da'],
#  [7.801083770777569e-12, 1.50614, 'SN2005am'],
#  [5.085624766620414e-12, 1.27784, 'SN2002bo'],
#  [1.1915338713179714e-11, 3.16247, 'SN2007on'],
#  [3.2654707371601605e-13, 0.0623521, 'SN2002hw'],
#  [6.213347781334993e-13, 0.112941, 'SN2002de'],
#  [2.853652437844946e-12, 0.519591, 'SN2001bf'],
#  [7.0160887368022715e-12, 1.45675, 'SN2015bp'],
#  [3.404043705781089e-11, 9.30609, 'SN1994D'],
#  [5.070457195879889e-13, 0.191828, 'SN2007qe'],
#  [3.1287289944707503e-12, 0.501016, 'SN2002ha'],
#  [2.0283447989609603e-12, 0.38955, 'iPTF13dge'],
#  [8.857856249789007e-12, 1.84043, 'SN1999by'],
#  [2.7202133192401274e-12, 0.599179, 'SN1999aa'],
#  [3.265841611619418e-11, 5.98842, 'SN1998aq'],
#  [3.558594105618115e-12, 0.460053, 'SN2006ax'],
#  [2.3154911736394135e-13, 0.0374533, 'SN2006gj'],
#  [3.3515231579941635e-12, 0.69834, 'SN2002dp'],
#  [1.6144539548225145e-11, 1.70722, 'SN2012hr'],
#  [3.08587230711755e-12, 0.909703, 'SN2009Y'],
#  [1.0828533592463709e-11, 2.14464, 'SN1995D'],
#  [8.262282496482041e-12, 1.35742, 'SN2007le'],
#  [4.558714130904519e-13, 0.0709181, 'SN2002fb'],
#  [1.5683860816230151e-12, 0.14237, 'SN2008Z'],
#  [4.296497395623115e-11, 7.99236, 'SN2012fr'],
#  [1.5719847085865025e-11, 2.56275, 'SN2007af'],
#  [1.2829688870144144e-12, 0.213995, 'SN2006cp'],
#  [2.0948406993102356e-13, 0.0464778, 'SN2007kk'],
#  [1.4575320878418206e-12, 0.24122, 'SN2007hj'],
#  [1.0301380256234189e-12, 0.204767, 'SN2005kc'],
#  [5.984263612273444e-12, 0.718497, 'SN2001V'],
#  [9.590924382275618e-13, 0.21715, 'SN2007ci'],
#  [2.9994628252308587e-13, 0.0706362, 'SN2006gr'],
#  [8.063045622042899e-13, 0.178037, 'SN2001cp'],
#  [5.5521098644877915e-12, 0.775376, 'SN2003kf'],
#  [1.0353756874851755e-11, 2.141, 'SN2003du'],
#  [2.7292781731054507e-12, 0.519133, 'SN2001ep'],
#  [1.2119993543449876e-12, 0.255357, 'SN2008bf']]

# %%
# %matplotlib notebook

for i in range(0,len(list_data)):
    
    plt.plot(list_data[i][0],list_data[i][1])
    
    
#plt.ylim(0,7*10**(-11))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# %matplotlib inline
plt.plot(x_lc,z_lc,'ko')
plt.show()

# %%
max(z_lc)
# Out:
# 1.2119993543449876e-12

# %%
z_lc
# Out:
# [3.640141398932589e-13,
#  4.483556921061157e-13,
#  5.386232574314907e-13,
#  6.356803961408868e-13,
#  7.284628156021881e-13,
#  8.228337724047844e-13,
#  9.129450065469922e-13,
#  9.957701612921622e-13,
#  1.0683996571130406e-12,
#  1.1282072287784462e-12,
#  1.173018814234727e-12,
#  1.2012480638732738e-12,
#  1.2119993543449876e-12,
#  1.2051285175373127e-12,
#  1.1812446708612739e-12,
#  1.1416737135631507e-12,
#  1.088355689125978e-12,
#  1.023720004017991e-12,
#  9.505195009466034e-13,
#  8.65634998508866e-13,
#  7.900139795085634e-13,
#  7.082845641037047e-13,
#  6.288474019731623e-13,
#  5.536647207267327e-13,
#  4.842233979848163e-13,
#  4.2151616743484847e-13,
#  3.6606136361570225e-13,
#  3.179505562650875e-13,
#  2.769234608494807e-13,
#  2.424536116173179e-13,
#  2.1383913099048534e-13,
#  1.9028834995372567e-13,
#  1.7099678951340135e-13,
#  1.5520547540959977e-13,
#  1.4224331647384019e-13,
#  1.3154985419446249e-13,
#  1.2268234122039056e-13,
#  1.1530784962595332e-13,
#  1.0918716381107129e-13,
#  1.0415151913341113e-13,
#  1.0007861663516564e-13,
#  9.687006592244634e-14,
#  9.443261306801171e-14,
#  9.266566226740234e-14,
#  9.145453586051743e-14,
#  9.066960644381214e-14,
#  9.017088826685798e-14,
#  8.981544418373558e-14,
#  8.946686813808838e-14,
#  8.900522806202545e-14,
#  8.833541060935434e-14,
#  8.739326936705257e-14,
#  8.614904013270106e-14,
#  8.460755607895275e-14,
#  8.280446960724292e-14,
#  8.080150369343305e-14,
#  7.867809930120428e-14,
#  7.652313214171032e-14,
#  7.442570042974655e-14,
#  7.246679209352582e-14,
#  7.071253475953085e-14]

# %%
save_path = '/home/joao/Documentos/PCA'

# %%
table = []
for l in range(0,len(names)):
    table.append((names[l],factors[l]))

name_of_file = "factors"

completeName = os.path.join(save_path, name_of_file+".txt")

f = open(completeName, 'w')
f.write(tabulate(table, tablefmt="plain"))
f.close()

# %%
factors
# Out:
# [129932993273.52661,
#  366338831740.1357,
#  227468775597.262,
#  182145138764.8184,
#  182894557202.23328,
#  218325501338.81915,
#  219264776039.55063,
#  144270968857.23813,
#  178743924561.8627,
#  253466913933.20514,
#  287888784777.4655,
#  122905493978.98132,
#  343130025199.2192,
#  140251144954.00024,
#  134079494391.25183,
#  176951585198.11465,
#  236370457136.89957,
#  204058961742.44006,
#  228850734233.96814,
#  234821223726.4666,
#  269239881408.07825,
#  241462777463.5247,
#  158444347636.5091,
#  182922410099.61786,
#  192372446644.17776,
#  121428194050.76656,
#  191652726112.65234,
#  367191322661.94464,
#  234664774450.65448,
#  248230031761.23688,
#  150653242050.14948,
#  97136601466.65584,
#  193068045960.73148,
#  251265096942.88202,
#  265411674491.63235,
#  190943680157.50446,
#  181771573030.6885,
#  182079286569.45718,
#  207629928104.92078,
#  273383387651.4412,
#  378324858270.915,
#  160134035541.4039,
#  192053146092.09976,
#  207773748873.36188,
#  220269122190.52603,
#  183365291773.30646,
#  129279425061.06367,
#  161750994460.20398,
#  208364963355.33185,
#  105745970326.39954,
#  294796060712.48456,
#  198054517879.74286,
#  164291162953.8169,
#  155566017002.97614,
#  90774842794.23792,
#  186020361798.47095,
#  163026394977.10977,
#  166796718272.71344,
#  221867944494.79456,
#  165498929328.66843,
#  198776275515.19528,
#  120064396649.63896,
#  226411961292.59576,
#  235496167533.14276,
#  220806142424.99045,
#  139654297001.4755,
#  206784843982.60074,
#  190208900329.6119,
#  210690706298.27606]
